# %%
# Import necessary packages:
import pandas as pd
import os
import numpy as np
import math
import pickle
import copy
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.model_selection import train_test_split
print('|---STEP 2: PROCESSING TADPOLE DATA ---|')








#--------------- PART 1: Loading preprocessed data ---------------#
print('|1/5| Loading preprocessed data...')

# Load preprocessed TADPOLE data
current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
processed_path = parent_directory + '/data/processed'

with open(processed_path + '/2_tadpole_data_processed.pickle', 'rb') as file:
    data = pickle.load(file)

with open(processed_path + '/2_tadpole_labels_processed.pickle', 'rb') as file:
    labels = pickle.load(file)
# Out:
# |---STEP 2: PROCESSING TADPOLE DATA ---|
# |1/5| Loading preprocessed data...

# %%
data['mci_bl']['train']['other']
# Out:
#     DX_bl   AGE PTGENDER  PTEDUCAT       PTETHCAT PTRACCAT  PTMARRY  APOE4  \
# 476  EMCI  71.7   Female        12  NotHispLatino    White  Married    1.0
# 836  LMCI  76.1     Male        20  NotHispLatino    White  Married    1.0
# 796  EMCI  61.8     Male        20  NotHispLatino    White  Married    0.0
# 494  EMCI  70.6     Male        16  NotHispLatino    White  Married    0.0
# 94   LMCI  71.5   Female        16  NotHispLatino    White  Married    1.0
# ..    ...   ...      ...       ...            ...      ...      ...    ...
# 110  LMCI  74.7     Male        16  NotHispLatino    White  Married    1.0
# 290  LMCI  80.2     Male        16  NotHispLatino    Black  Married    0.0
# 454  EMCI  78.6   Female        18  NotHispLatino    White  Married    0.0
# 15   LMCI  85.0     Male        18  NotHispLatino    White  Married    1.0
# 452  EMCI  65.7     Male        19  NotHispLatino    White  Married    0.0
#
#          FDG
# 476  1.24136
# 836  1.26727
# 796  1.31228
# ...
